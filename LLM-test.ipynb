# %%
RAG="I would like to go to travel to a city with historical monuments and beautiful landscapes. Can you suggest a place for me to visit?"

# %%
CSV_PATH = Path("Attractions.csv")

# %%
from google import genai

haca = "AIzaSyDCCiI2WB5ppfAK11WcW1cH_ldKr3g3rUU"
client = genai.Client(api_key=haca)

prompt = f"""
You are a travel recommendation assistant.

RULES:
- Only consider locations that are in Ireland.
- From the information given be the DATA (RAG CONTENT) find the priorities, pick the TOP 3 best matching locations in Ireland.
- If fewer than 3 Iris locations exist in the data, return as many as you can.
- Each location must be unique.
- Briefly explain WHY each locations was selected.
- Output shall be given by a JSON array

{RAG}
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt,
)

print(response.text)
# Out:
# ```json
# [
#   {
#     "location": "Dublin",
#     "reason": "As Ireland's capital, Dublin boasts a rich array of historical monuments such as Dublin Castle, St. Patrick's Cathedral, and Trinity College. It also offers beautiful urban landscapes like Phoenix Park and convenient access to stunning coastal areas like Howth and the picturesque Wicklow Mountains."
#   },
#   {
#     "location": "Galway",
#     "reason": "Galway is a vibrant city with a charming historic core, including sites like the Spanish Arch. It serves as a gateway to some of Ireland's most breathtaking landscapes, being situated on Galway Bay and offering easy access to the dramatic Connemara region, the Cliffs of Moher, and the Aran Islands."
#   },
#   {
#     "location": "Killarney, County Kerry",
# ...

# %%
import json

text = response.text.strip()

# If it's wrapped in ```json ... ``` fences, strip them
if text.startswith("```"):
    # remove the first line (```json or ```)
    text = text.split("\n", 1)[1]
    # remove the trailing ```
    if text.endswith("```"):
        text = text.rsplit("\n", 1)[0]

arr = json.loads(text)
print(arr)
# Out:
# [{'location': 'Dublin', 'reason': "As Ireland's capital, Dublin boasts a rich array of historical monuments such as Dublin Castle, St. Patrick's Cathedral, and Trinity College. It also offers beautiful urban landscapes like Phoenix Park and convenient access to stunning coastal areas like Howth and the picturesque Wicklow Mountains."}, {'location': 'Galway', 'reason': "Galway is a vibrant city with a charming historic core, including sites like the Spanish Arch. It serves as a gateway to some of Ireland's most breathtaking landscapes, being situated on Galway Bay and offering easy access to the dramatic Connemara region, the Cliffs of Moher, and the Aran Islands."}, {'location': 'Killarney, County Kerry', 'reason': "Killarney is a renowned tourist town nestled amidst spectacular natural beauty within Killarney National Park. It's home to historical monuments like Ross Castle and Muckross Abbey, surrounded by the stunning Lakes of Killarney and serving as a perfect base for exploring 
# ...
